# %% [markdown]
# # Crawler:

# %%
import re
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

# %%
from nltk.tokenize import word_tokenize
from nltk import WordNetLemmatizer
from nltk.corpus import stopwords, wordnet

stop_words = stopwords.words("english")

# %%
class Crawler:
    def __init__(self):
        self.links_to_visit = []
        self.visited_links = []
        self.inv_index = dict()
        self.tf = dict()
        self.df = dict()
        self.doc_length = dict()


    def get_new_link(self):
        current_link = self.links_to_visit.pop()
        while (current_link in self.visited_links) and (len(self.links_to_visit) > 0):
            current_link = self.links_to_visit.pop()
        return current_link


    def extract_links(self, content):
        all_links = re.findall(r'<a href="(https://www.bbc.com/[^"]+)', content)
        self.links_to_visit.extend(all_links)


    def find_paragraphs(self, content):
        soup = BeautifulSoup(content, 'html.parser')
        paragraphs = soup.find_all('p')
        headings1 = soup.find_all('h1')
        headings2 = soup.find_all('h2')
        headings3 = soup.find_all('h3')
        headings4 = soup.find_all('h4')
        headings5 = soup.find_all('h5')
        headings6 = soup.find_all('h6')
        text = ''

        for headings in [headings1, headings2, headings3, headings4, headings5, headings6]:
            for h in headings:
                text += h.get_text(separator='\n') + '\n'

        for p in paragraphs:
            text += p.get_text(separator='\n') + '\n'

        return text


    def tf_m(self, term, doc, ln):
        tf1 = dict()
        l = term + '.' + doc
        if l in self.tf.keys():
            tf1[l] = self.tf[l]*ln + 1
        else:
            tf1[l] = 1
        self.tf[l] = tf1[l]/ln


    def inverted_index(self, text, current_link):
        wn_lemmatizer = WordNetLemmatizer()
        tokens = word_tokenize(text)
        self.doc_length[current_link] = len(tokens)
        tok = set()
        for t in tokens:
            t = t.lower()
            if t not in stop_words and t.isalpha():
                t = wn_lemmatizer.lemmatize(t)
                tok.add(t)
                self.tf_m(t, current_link, len(tokens))             #TF
                if t in self.inv_index.keys():
                    l = self.inv_index[t]
                    if current_link not in l:
                        l.append(current_link)
                elif t not in self.inv_index.keys():
                    l = [current_link]
                self.inv_index.update({t:l})

        #df
        for t in tok:
            if t in self.df.keys():
                self.df[t] += 1
            else:
                self.df[t] = 1


    def crawl(self, start_url, max_links):
        self.links_to_visit = [start_url]
        while (len(self.links_to_visit) > 0) and (len(self.visited_links) < max_links):
            current_link = self.get_new_link()
            try:
                res = requests.get(current_link)
                if res.status_code == 200:
                    page_content = res.content
                    paragraph = self.find_paragraphs(page_content)
                    self.inverted_index(paragraph, current_link)
                    self.extract_links(str(page_content))
                    self.visited_links.append(current_link)
            except Exception as e:
                print(f"Error crawling {current_link}: {e}")

# %% [markdown]
# # Search:

# %%
def find_docs(term, inv_index):
    term = term.lower()
    wn_lemmatizer = WordNetLemmatizer()
    word = wn_lemmatizer.lemmatize(term)
    synset = wordnet.synsets(word)
    synonyms = [s.name().split('.')[0] for s in synset]
    synonyms.append(word)
    synonyms = list(set(synonyms))
    docs_ids = []
    for s in synonyms:
        m = inv_index.get(s)
        if m:
            docs_ids.extend(m)
    return docs_ids

# %%
def search(term, inv_index):
    all_docs = []
    for i in range(len(term)):
        all_docs.extend(find_docs(term[i], inv_index))
    doc = list(set(i for i in all_docs if all_docs.count(i) == len(term)))
    doc.sort()
    return doc

# %% [markdown]
# # TF_IDF:

# %%
def tf_idf(term, doc, crawler):
    tf = crawler.tf.get(term + '.' + doc)
    df = crawler.df.get(term)
    if tf and df:
        idf = np.log10(len(crawler.inv_index.keys()) / (df + 1))
        return tf * idf
    else:
        return 0

# %%
def sort_tf_idf(terms, res_docs, crawler):
    tf_idf_t = dict()
    tf_idf_d = dict()
    for d in res_docs:
        for t in terms:
            tf_idf_t[d+t] = tf_idf(t, d, crawler)
            if d in tf_idf_d.keys():
                tf_idf_d[d] += tf_idf_t[d+t]
            else:
                tf_idf_d[d] = tf_idf_t[d+t]
    sorted_dict = dict(sorted(tf_idf_d.items(), key=lambda item: item[1]))
    l = list(sorted_dict.keys())
    return l

# %% [markdown]
# # Okapi bm25f:

# %%
def okapi_bm25f(term, doc, crawler, k1, b):
    tf = crawler.tf.get(term + '.' + doc)
    df = crawler.df.get(term)
    if tf and df:
        idf = np.log10(len(crawler.inv_index.keys()) / (df + 1))
        avg_doc_length = sum(crawler.doc_length.values())/len(crawler.doc_length.keys())
        return idf * (tf * (k1 + 1)) / (tf + k1 * (1 - b + b * (crawler.doc_length[doc] / avg_doc_length)))
    else:
        return

# %%
def search_okapi_bm25f(terms, crawler, res_docs, k1=1.5, b=0.75):
    okapi_bm25f_scores = {}
    for doc_id in res_docs:
        okapi_bm25f_scores[doc_id] = sum(okapi_bm25f(term, doc_id, crawler, k1, b) for term in terms)

    if not okapi_bm25f_scores:  # No matching documents
        return list(res_docs)

    # Sort documents by Okapi BM25F scores in descending order
    sorted_docs = sorted(okapi_bm25f_scores.keys(), key=lambda x: okapi_bm25f_scores[x], reverse=True)
    return sorted_docs

# %% [markdown]
# # Test:

# %%
crawler=Crawler()
crawler.crawl("https://www.bbc.com/news",10)

# %%
crawler.inv_index
# Out:
# {'bbc': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/culture',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife',
#   'https://www.bbc.com/reel',
#   'https://www.bbc.com/future/earth'],
#  'news': ['https://www.bbc.com/news'],
#  'home': ['https://www.bbc.com/news', 'https://www.bbc.com/culture'],
#  'accessibility': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/culture',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife',
#   'https://www.bbc.com/reel',
#   'https://www.bbc.com/future/earth'],
#  'link': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/culture',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife',
#   'https://www.bbc.com/reel',
#   'https://www.bbc.com/future/earth'],
#  'navigation': ['https://www.bbc.com/news'],
#  'breaking': ['https://www.bbc.com/news'],
#  'top': ['https://www.bbc.com/news'],
#  'story': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'yemen': ['https://www.bbc.com/news'],
#  'strike': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'feature': ['https://www.bbc.com/news',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/worklife'],
#  'analysis': ['https://www.bbc.com/news'],
#  'watched': ['https://www.bbc.com/news'],
#  'also': ['https://www.bbc.com/news'],
#  'war': ['https://www.bbc.com/news'],
#  'read': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'around': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/privacy/',
#   'https://www.bbc.com/weather'],
#  'sport': ['https://www.bbc.com/news'],
#  'find': ['https://www.bbc.com/news'],
#  'u': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/culture',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife',
#   'https://www.bbc.com/reel'],
#  'explore': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/culture',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife',
#   'https://www.bbc.com/reel',
#   'https://www.bbc.com/future/earth'],
#  'launch': ['https://www.bbc.com/news'],
#  'new': ['https://www.bbc.com/news',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife',
#   'https://www.bbc.com/future/earth'],
#  'missile': ['https://www.bbc.com/news'],
#  'houthi': ['https://www.bbc.com/news'],
#  'target': ['https://www.bbc.com/news'],
#  'william': ['https://www.bbc.com/news'],
#  'lai': ['https://www.bbc.com/news'],
#  'labelled': ['https://www.bbc.com/news'],
#  'troublemaker': ['https://www.bbc.com/news'],
#  'china': ['https://www.bbc.com/news'],
#  'lead': ['https://www.bbc.com/news'],
#  'taiwan': ['https://www.bbc.com/news'],
#  'poll': ['https://www.bbc.com/news'],
#  'jacinda': ['https://www.bbc.com/news'],
#  'ardern': ['https://www.bbc.com/news'],
#  'marries': ['https://www.bbc.com/news'],
#  'partner': ['https://www.bbc.com/news'],
#  'private': ['https://www.bbc.com/news'],
#  'ceremony': ['https://www.bbc.com/news'],
#  'tough': ['https://www.bbc.com/news'],
#  'choice': ['https://www.bbc.com/news'],
#  'israel': ['https://www.bbc.com/news'],
#  'middle': ['https://www.bbc.com/news'],
#  'east': ['https://www.bbc.com/news'],
#  'vision': ['https://www.bbc.com/news'],
#  'africa': ['https://www.bbc.com/news'],
#  'play': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'heavy': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'emotion': ['https://www.bbc.com/news'],
#  'genocide': ['https://www.bbc.com/news'],
#  'case': ['https://www.bbc.com/news'],
#  'south': ['https://www.bbc.com/news'],
#  'korea': ['https://www.bbc.com/news'],
#  'complicated': ['https://www.bbc.com/news'],
#  'relationship': ['https://www.bbc.com/news'],
#  'dog': ['https://www.bbc.com/news'],
#  'meat': ['https://www.bbc.com/news'],
#  'macron': ['https://www.bbc.com/news'],
#  'help': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/cookies/'],
#  'fend': ['https://www.bbc.com/news'],
#  'far': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'right': ['https://www.bbc.com/news', 'https://www.bbc.com/culture'],
#  'ecuador': ['https://www.bbc.com/news'],
#  'violence': ['https://www.bbc.com/news'],
#  'affect': ['https://www.bbc.com/news'],
#  'whole': ['https://www.bbc.com/news'],
#  'world': ['https://www.bbc.com/news',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/reel',
#   'https://www.bbc.com/future/earth'],
#  'president': ['https://www.bbc.com/news'],
#  'tell': ['https://www.bbc.com/news', 'https://www.bbc.com/future'],
#  'amazon': ['https://www.bbc.com/news'],
#  'deforestation': ['https://www.bbc.com/news'],
#  'rate': ['https://www.bbc.com/news'],
#  'dropped': ['https://www.bbc.com/news'],
#  'trump': ['https://www.bbc.com/news'],
#  'asked': ['https://www.bbc.com/news'],
#  'pay': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'ny': ['https://www.bbc.com/news'],
#  'time': ['https://www.bbc.com/news',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'legal': ['https://www.bbc.com/news'],
#  'cost': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'winter': ['https://www.bbc.com/news',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/future/earth'],
#  'storm': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'hit': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'snow': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'icy': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'wind': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'medicine': ['https://www.bbc.com/news'],
#  'sent': ['https://www.bbc.com/news'],
#  'gaza': ['https://www.bbc.com/news'],
#  'hostage': ['https://www.bbc.com/news'],
#  'israeli': ['https://www.bbc.com/news'],
#  'pm': ['https://www.bbc.com/news'],
#  'musician': ['https://www.bbc.com/news'],
#  'jelly': ['https://www.bbc.com/news'],
#  'roll': ['https://www.bbc.com/news'],
#  'push': ['https://www.bbc.com/news'],
#  'bill': ['https://www.bbc.com/news'],
#  'increase': ['https://www.bbc.com/news'],
#  'oversight': ['https://www.bbc.com/news'],
#  'boeing': ['https://www.bbc.com/news'],
#  'blowout': ['https://www.bbc.com/news'],
#  'italian': ['https://www.bbc.com/news', 'https://www.bbc.com/travel'],
#  'deputy': ['https://www.bbc.com/news'],
#  'take': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/worklife'],
#  'stand': ['https://www.bbc.com/news'],
#  'migrant': ['https://www.bbc.com/news'],
#  'kidnap': ['https://www.bbc.com/news'],
#  'trial': ['https://www.bbc.com/news'],
#  'show': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/cookies/'],
#  'already': ['https://www.bbc.com/news'],
#  'spread': ['https://www.bbc.com/news'],
#  'know': ['https://www.bbc.com/news'],
#  'houthis': ['https://www.bbc.com/news'],
#  'strategy': ['https://www.bbc.com/news'],
#  'behind': ['https://www.bbc.com/news'],
#  'listen': ['https://www.bbc.com/news'],
#  'uk': ['https://www.bbc.com/news',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/travel'],
#  'attacking': ['https://www.bbc.com/news'],
#  'oil': ['https://www.bbc.com/news', 'https://www.bbc.com/travel'],
#  'price': ['https://www.bbc.com/news', 'https://www.bbc.com/travel'],
#  'rise': ['https://www.bbc.com/news'],
#  'democrat': ['https://www.bbc.com/news'],
#  'attack': ['https://www.bbc.com/news'],
#  'biden': ['https://www.bbc.com/news'],
#  'rebel': ['https://www.bbc.com/news'],
#  'need': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/',
#   'https://www.bbc.com/weather'],
#  'jungle': ['https://www.bbc.com/news'],
#  'amol': ['https://www.bbc.com/news'],
#  'rajan': ['https://www.bbc.com/news'],
#  'tv': ['https://www.bbc.com/news',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/culture'],
#  'quiz': ['https://www.bbc.com/news'],
#  'remix': ['https://www.bbc.com/news'],
#  'craze': ['https://www.bbc.com/news'],
#  'service': ['https://www.bbc.com/news'],
#  'radio': ['https://www.bbc.com/news'],
#  'eye': ['https://www.bbc.com/news'],
#  'iowa': ['https://www.bbc.com/news'],
#  'republican': ['https://www.bbc.com/news'],
#  'gear': ['https://www.bbc.com/news'],
#  'choose': ['https://www.bbc.com/news', 'https://www.bbc.com/culture'],
#  'candidate': ['https://www.bbc.com/news'],
#  'nightclub': ['https://www.bbc.com/news'],
#  'open': ['https://www.bbc.com/news'],
#  'day': ['https://www.bbc.com/news',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/future'],
#  'election': ['https://www.bbc.com/news'],
#  'matter': ['https://www.bbc.com/news'],
#  'france': ['https://www.bbc.com/news'],
#  'tilt': ['https://www.bbc.com/news'],
#  'cabinet': ['https://www.bbc.com/news'],
#  'maestro': ['https://www.bbc.com/news'],
#  'took': ['https://www.bbc.com/news'],
#  'classical': ['https://www.bbc.com/news'],
#  'music': ['https://www.bbc.com/news', 'https://www.bbc.com/culture'],
#  'india': ['https://www.bbc.com/news'],
#  'mass': ['https://www.bbc.com/news'],
#  'huge': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'ancient': ['https://www.bbc.com/news',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/travel'],
#  'city': ['https://www.bbc.com/news', 'https://www.bbc.com/travel'],
#  'found': ['https://www.bbc.com/news'],
#  'noticed': ['https://www.bbc.com/news'],
#  'bulging': ['https://www.bbc.com/news'],
#  'lump': ['https://www.bbc.com/news'],
#  'sensation': ['https://www.bbc.com/news'],
#  'vagina': ['https://www.bbc.com/news'],
#  'first': ['https://www.bbc.com/news'],
#  'west': ['https://www.bbc.com/news'],
#  'african': ['https://www.bbc.com/news'],
#  'nation': ['https://www.bbc.com/news'],
#  'status': ['https://www.bbc.com/news'],
#  'ai': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'pillow': ['https://www.bbc.com/news'],
#  'toothbrush': ['https://www.bbc.com/news'],
#  'getting': ['https://www.bbc.com/news'],
#  'bit': ['https://www.bbc.com/news'],
#  'silly': ['https://www.bbc.com/news'],
#  'ebay': ['https://www.bbc.com/news'],
#  'fine': ['https://www.bbc.com/news'],
#  'blogger': ['https://www.bbc.com/news'],
#  'harassment': ['https://www.bbc.com/news'],
#  'hunter': ['https://www.bbc.com/news'],
#  'pleads': ['https://www.bbc.com/news'],
#  'guilty': ['https://www.bbc.com/news'],
#  'nine': ['https://www.bbc.com/news', 'https://www.bbc.com/future/earth'],
#  'tax': ['https://www.bbc.com/news'],
#  'charge': ['https://www.bbc.com/news'],
#  'iranian': ['https://www.bbc.com/news'],
#  'navy': ['https://www.bbc.com/news'],
#  'seizes': ['https://www.bbc.com/news'],
#  'tanker': ['https://www.bbc.com/news'],
#  'near': ['https://www.bbc.com/news'],
#  'oman': ['https://www.bbc.com/news'],
#  'reporter': ['https://www.bbc.com/news'],
#  'family': ['https://www.bbc.com/news'],
#  'reject': ['https://www.bbc.com/news'],
#  'terrorist': ['https://www.bbc.com/news'],
#  'claim': ['https://www.bbc.com/news'],
#  'life': ['https://www.bbc.com/news', 'https://www.bbc.com/future'],
#  'ruin': ['https://www.bbc.com/news'],
#  'finnish': ['https://www.bbc.com/news'],
#  'artist': ['https://www.bbc.com/news'],
#  'want': ['https://www.bbc.com/news'],
#  'barred': ['https://www.bbc.com/news'],
#  'eurovision': ['https://www.bbc.com/news'],
#  'concern': ['https://www.bbc.com/news'],
#  'hospital': ['https://www.bbc.com/news'],
#  'staff': ['https://www.bbc.com/news'],
#  'pulled': ['https://www.bbc.com/news'],
#  'blinken': ['https://www.bbc.com/news'],
#  'child': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'high': ['https://www.bbc.com/news'],
#  'avoid': ['https://www.bbc.com/news',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/travel'],
#  'dystopian': ['https://www.bbc.com/news', 'https://www.bbc.com/future'],
#  'thinking': ['https://www.bbc.com/news', 'https://www.bbc.com/future'],
#  'mocktails': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'scratch': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'dry': ['https://www.bbc.com/news',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/worklife'],
#  'january': ['https://www.bbc.com/news',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/worklife'],
#  'itch': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'mysterious': ['https://www.bbc.com/news', 'https://www.bbc.com/travel'],
#  'dance': ['https://www.bbc.com/news', 'https://www.bbc.com/travel'],
#  'million': ['https://www.bbc.com/news', 'https://www.bbc.com/travel'],
#  'starling': ['https://www.bbc.com/news', 'https://www.bbc.com/travel'],
#  'amy': ['https://www.bbc.com/news', 'https://www.bbc.com/culture'],
#  'winehouse': ['https://www.bbc.com/news', 'https://www.bbc.com/culture'],
#  'film': ['https://www.bbc.com/news', 'https://www.bbc.com/culture'],
#  'angering': ['https://www.bbc.com/news', 'https://www.bbc.com/culture'],
#  'fan': ['https://www.bbc.com/news', 'https://www.bbc.com/culture'],
#  'symptom': ['https://www.bbc.com/news', 'https://www.bbc.com/future'],
#  'changed': ['https://www.bbc.com/news',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/culture',
#   'https://www.bbc.com/worklife',
#   'https://www.bbc.com/future/earth'],
#  'author': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'michael': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'lewis': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'uncovers': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'hidden': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'paris': ['https://www.bbc.com/news', 'https://www.bbc.com/travel'],
#  'restaurant': ['https://www.bbc.com/news', 'https://www.bbc.com/travel'],
#  'get': ['https://www.bbc.com/news',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife'],
#  'big': ['https://www.bbc.com/news',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/future/earth'],
#  'update': ['https://www.bbc.com/news', 'https://www.bbc.com/travel'],
#  'salah': ['https://www.bbc.com/news'],
#  'win': ['https://www.bbc.com/news', 'https://www.bbc.com/future/earth'],
#  'afcon': ['https://www.bbc.com/news'],
#  'title': ['https://www.bbc.com/news'],
#  'amid': ['https://www.bbc.com/news'],
#  'strong': ['https://www.bbc.com/news'],
#  'field': ['https://www.bbc.com/news'],
#  'gauff': ['https://www.bbc.com/news'],
#  'least': ['https://www.bbc.com/news'],
#  'grand': ['https://www.bbc.com/news'],
#  'slam': ['https://www.bbc.com/news'],
#  'decision': ['https://www.bbc.com/news'],
#  'luton': ['https://www.bbc.com/news'],
#  'goal': ['https://www.bbc.com/news'],
#  'stood': ['https://www.bbc.com/news'],
#  'record': ['https://www.bbc.com/news'],
#  'could': ['https://www.bbc.com/news'],
#  'djokovic': ['https://www.bbc.com/news'],
#  'set': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'kane': ['https://www.bbc.com/news'],
#  'score': ['https://www.bbc.com/news'],
#  'bayern': ['https://www.bbc.com/news'],
#  'night': ['https://www.bbc.com/news'],
#  'tribute': ['https://www.bbc.com/news'],
#  'beckenbauer': ['https://www.bbc.com/news'],
#  'thompson': ['https://www.bbc.com/news'],
#  'curry': ['https://www.bbc.com/news'],
#  'warrior': ['https://www.bbc.com/news'],
#  'bull': ['https://www.bbc.com/news'],
#  'patriot': ['https://www.bbc.com/news'],
#  'replace': ['https://www.bbc.com/news'],
#  'belichick': ['https://www.bbc.com/news'],
#  'mayo': ['https://www.bbc.com/news'],
#  'daily': ['https://www.bbc.com/news'],
#  'newsletter': ['https://www.bbc.com/news', 'https://www.bbc.com/future'],
#  'mobile': ['https://www.bbc.com/news'],
#  'app': ['https://www.bbc.com/news'],
#  'touch': ['https://www.bbc.com/news'],
#  'related': ['https://www.bbc.com/news'],
#  'content': ['https://www.bbc.com/news'],
#  'ship': ['https://www.bbc.com/news'],
#  'radar': ['https://www.bbc.com/news'],
#  'site': ['https://www.bbc.com/news'],
#  'wider': ['https://www.bbc.com/news'],
#  'vow': ['https://www.bbc.com/news'],
#  'effective': ['https://www.bbc.com/news'],
#  'response': ['https://www.bbc.com/news'],
#  'appears': ['https://www.bbc.com/news'],
#  'leading': ['https://www.bbc.com/news'],
#  'two': ['https://www.bbc.com/news'],
#  'opponent': ['https://www.bbc.com/news'],
#  'presidential': ['https://www.bbc.com/news'],
#  'zealand': ['https://www.bbc.com/news', 'https://www.bbc.com/future/earth'],
#  'former': ['https://www.bbc.com/news'],
#  'presenter': ['https://www.bbc.com/news'],
#  'clarke': ['https://www.bbc.com/news'],
#  'gayford': ['https://www.bbc.com/news'],
#  'hawke': ['https://www.bbc.com/news'],
#  'bay': ['https://www.bbc.com/news'],
#  'vineyard': ['https://www.bbc.com/news'],
#  'plan': ['https://www.bbc.com/news'],
#  'see': ['https://www.bbc.com/news',
#   'https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'diplomatic': ['https://www.bbc.com/news'],
#  'normalisation': ['https://www.bbc.com/news'],
#  'arab': ['https://www.bbc.com/news'],
#  'neighbour': ['https://www.bbc.com/news'],
#  'end': ['https://www.bbc.com/news',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/worklife'],
#  'offensive': ['https://www.bbc.com/news'],
#  'argument': ['https://www.bbc.com/news'],
#  'judge': ['https://www.bbc.com/news'],
#  'must': ['https://www.bbc.com/news'],
#  'rule': ['https://www.bbc.com/news'],
#  'whether': ['https://www.bbc.com/news'],
#  'committing': ['https://www.bbc.com/news'],
#  'issue': ['https://www.bbc.com/news'],
#  'divide': ['https://www.bbc.com/news'],
#  'along': ['https://www.bbc.com/news'],
#  'age': ['https://www.bbc.com/news'],
#  'line': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'come': ['https://www.bbc.com/news'],
#  'fore': ['https://www.bbc.com/news'],
#  'law': ['https://www.bbc.com/news'],
#  'passed': ['https://www.bbc.com/news'],
#  'youngest': ['https://www.bbc.com/news'],
#  'popular': ['https://www.bbc.com/news',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife'],
#  'public': ['https://www.bbc.com/news'],
#  'long': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'honeymoon': ['https://www.bbc.com/news'],
#  'period': ['https://www.bbc.com/news'],
#  'last': ['https://www.bbc.com/news',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/culture'],
#  'daniel': ['https://www.bbc.com/news'],
#  'noboa': ['https://www.bbc.com/news'],
#  'say': ['https://www.bbc.com/news'],
#  'wo': ['https://www.bbc.com/news', 'https://www.bbc.com/worklife'],
#  'let': ['https://www.bbc.com/news'],
#  'country': ['https://www.bbc.com/news'],
#  'turn': ['https://www.bbc.com/news'],
#  'gang': ['https://www.bbc.com/news'],
#  'preliminary': ['https://www.bbc.com/news'],
#  'data': ['https://www.bbc.com/news'],
#  'sq': ['https://www.bbc.com/news'],
#  'km': ['https://www.bbc.com/news'],
#  'cleared': ['https://www.bbc.com/news'],
#  'still': ['https://www.bbc.com/news'],
#  'six': ['https://www.bbc.com/news'],
#  'size': ['https://www.bbc.com/news'],
#  'york': ['https://www.bbc.com/news'],
#  'expense': ['https://www.bbc.com/news'],
#  'failed': ['https://www.bbc.com/news'],
#  'lawsuit': ['https://www.bbc.com/news', 'https://www.bbc.com/future/earth'],
#  'filed': ['https://www.bbc.com/news'],
#  'paper': ['https://www.bbc.com/news'],
#  'nearly': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'every': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'state': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'watch': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'dangerous': ['https://www.bbc.com/news',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/future/earth'],
#  'freezing': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'cold': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'call': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'reason': ['https://www.bbc.com/news',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/travel'],
#  'qatar': ['https://www.bbc.com/news'],
#  'helped': ['https://www.bbc.com/news'],
#  'agree': ['https://www.bbc.com/news'],
#  'deal': ['https://www.bbc.com/news'],
#  'hamas': ['https://www.bbc.com/news'],
#  'raised': ['https://www.bbc.com/news'],
#  'drug': ['https://www.bbc.com/news'],
#  'dealer': ['https://www.bbc.com/news'],
#  'grammy': ['https://www.bbc.com/news'],
#  'nominee': ['https://www.bbc.com/news'],
#  'told': ['https://www.bbc.com/news'],
#  'lawmaker': ['https://www.bbc.com/news'],
#  'congress': ['https://www.bbc.com/news'],
#  'proactive': ['https://www.bbc.com/news'],
#  'air': ['https://www.bbc.com/news'],
#  'regulator': ['https://www.bbc.com/news'],
#  'reviewing': ['https://www.bbc.com/news'],
#  'delegate': ['https://www.bbc.com/news'],
#  'quality': ['https://www.bbc.com/news', 'https://www.bbc.com/future'],
#  'matteo': ['https://www.bbc.com/news'],
#  'salvini': ['https://www.bbc.com/news'],
#  'said': ['https://www.bbc.com/news'],
#  'acted': ['https://www.bbc.com/news'],
#  'national': ['https://www.bbc.com/news'],
#  'interest': ['https://www.bbc.com/news'],
#  'banning': ['https://www.bbc.com/news'],
#  'rescue': ['https://www.bbc.com/news'],
#  'docking': ['https://www.bbc.com/news'],
#  'italy': ['https://www.bbc.com/news'],
#  'latest': ['https://www.bbc.com/news',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'global': ['https://www.bbc.com/news'],
#  'weather': ['https://www.bbc.com/news', 'https://www.bbc.com/weather'],
#  'documentary': ['https://www.bbc.com/news'],
#  'email': ['https://www.bbc.com/news'],
#  'haveyoursay': ['https://www.bbc.com/news'],
#  'follow': ['https://www.bbc.com/news', 'https://www.bbc.com/reel'],
#  'twitter': ['https://www.bbc.com/news'],
#  'trust': ['https://www.bbc.com/news'],
#  'control': ['https://www.bbc.com/usingthebbc/cookies/'],
#  'cooky': ['https://www.bbc.com/usingthebbc/cookies/'],
#  'cookie': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/travel'],
#  'setting': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/weather'],
#  'rebuild': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'page': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'useful': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'theme': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'toggler': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'remember': ['https://www.bbc.com/usingthebbc/cookies/'],
#  'thing': ['https://www.bbc.com/usingthebbc/cookies/'],
#  'think': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/worklife'],
#  'like': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/travel'],
#  'browse': ['https://www.bbc.com/usingthebbc/cookies/'],
#  'use': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/future/earth'],
#  'change': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/future/earth'],
#  'suit': ['https://www.bbc.com/usingthebbc/cookies/'],
#  'automatically': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'reload': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'may': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife',
#   'https://www.bbc.com/future/earth'],
#  'build': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'longer': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'expected': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'select': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'mode': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'click': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'load': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'combination': ['https://www.bbc.com/usingthebbc/cookies/',
#   'https://www.bbc.com/usingthebbc/privacy/'],
#  'keeping': ['https://www.bbc.com/usingthebbc/privacy/'],
#  'info': ['https://www.bbc.com/usingthebbc/privacy/'],
#  'safe': ['https://www.bbc.com/usingthebbc/privacy/'],
#  'sound': ['https://www.bbc.com/usingthebbc/privacy/',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'personal': ['https://www.bbc.com/usingthebbc/privacy/'],
#  'information': ['https://www.bbc.com/usingthebbc/privacy/'],
#  'privacy': ['https://www.bbc.com/usingthebbc/privacy/'],
#  'activity': ['https://www.bbc.com/usingthebbc/privacy/'],
#  'safety': ['https://www.bbc.com/usingthebbc/privacy/'],
#  'seriously': ['https://www.bbc.com/usingthebbc/privacy/'],
#  'look': ['https://www.bbc.com/usingthebbc/privacy/',
#   'https://www.bbc.com/weather',
#   'https://www.bbc.com/future'],
#  'secure': ['https://www.bbc.com/usingthebbc/privacy/'],
#  'promise': ['https://www.bbc.com/usingthebbc/privacy/'],
#  'search': ['https://www.bbc.com/weather'],
#  'location': ['https://www.bbc.com/weather'],
#  'forecast': ['https://www.bbc.com/weather'],
#  'thousand': ['https://www.bbc.com/weather'],
#  'europe': ['https://www.bbc.com/weather', 'https://www.bbc.com/travel'],
#  'video': ['https://www.bbc.com/weather'],
#  'enable': ['https://www.bbc.com/weather'],
#  'javascript': ['https://www.bbc.com/weather'],
#  'browser': ['https://www.bbc.com/weather'],
#  'elsewhere': ['https://www.bbc.com/weather'],
#  'played': ['https://www.bbc.com/weather'],
#  'week': ['https://www.bbc.com/weather', 'https://www.bbc.com/culture'],
#  'ahead': ['https://www.bbc.com/weather'],
#  'turning': ['https://www.bbc.com/weather'],
#  'colder': ['https://www.bbc.com/weather'],
#  'next': ['https://www.bbc.com/weather',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'condition': ['https://www.bbc.com/weather'],
#  'go': ['https://www.bbc.com/weather', 'https://www.bbc.com/travel'],
#  'blast': ['https://www.bbc.com/weather'],
#  'store': ['https://www.bbc.com/weather'],
#  'coldest': ['https://www.bbc.com/weather'],
#  'move': ['https://www.bbc.com/weather',
#   'https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'stav': ['https://www.bbc.com/weather'],
#  'danaos': ['https://www.bbc.com/weather'],
#  'detail': ['https://www.bbc.com/weather'],
#  'matt': ['https://www.bbc.com/weather'],
#  'taylor': ['https://www.bbc.com/weather'],
#  'back': ['https://www.bbc.com/weather'],
#  'year': ['https://www.bbc.com/weather', 'https://www.bbc.com/travel'],
#  'mark': ['https://www.bbc.com/weather'],
#  'anniversary': ['https://www.bbc.com/weather'],
#  'broadcast': ['https://www.bbc.com/weather'],
#  'meteorologist': ['https://www.bbc.com/weather'],
#  'decade': ['https://www.bbc.com/weather'],
#  'association': ['https://www.bbc.com/weather'],
#  'meteogroup': ['https://www.bbc.com/weather'],
#  'external': ['https://www.bbc.com/weather'],
#  'greenwich': ['https://www.bbc.com/weather'],
#  'mean': ['https://www.bbc.com/weather'],
#  'gmt': ['https://www.bbc.com/weather'],
#  'unless': ['https://www.bbc.com/weather'],
#  'otherwise': ['https://www.bbc.com/weather'],
#  'stated': ['https://www.bbc.com/weather'],
#  'largest': ['https://www.bbc.com/future'],
#  'object': ['https://www.bbc.com/future'],
#  'universe': ['https://www.bbc.com/future'],
#  'rancher': ['https://www.bbc.com/future'],
#  'becoming': ['https://www.bbc.com/future'],
#  'beaver': ['https://www.bbc.com/future'],
#  'believer': ['https://www.bbc.com/future'],
#  'lost': ['https://www.bbc.com/future', 'https://www.bbc.com/culture'],
#  'practice': ['https://www.bbc.com/future'],
#  'communal': ['https://www.bbc.com/future'],
#  'sleep': ['https://www.bbc.com/future'],
#  'fight': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'constant': ['https://www.bbc.com/future'],
#  'itching': ['https://www.bbc.com/future'],
#  'sign': ['https://www.bbc.com/future'],
#  'climate': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'combat': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'ev': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'range': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'anxiety': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'forest': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'map': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'predicting': ['https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'poacher': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'canadian': ['https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'neighbourhood': ['https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'heated': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'sewage': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'microplastics': ['https://www.bbc.com/future'],
#  'everywhere': ['https://www.bbc.com/future'],
#  'possible': ['https://www.bbc.com/future'],
#  'reduce': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'exposure': ['https://www.bbc.com/future'],
#  'predict': ['https://www.bbc.com/future'],
#  'movement': ['https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'electric': ['https://www.bbc.com/future'],
#  'vehicle': ['https://www.bbc.com/future'],
#  'seasonal': ['https://www.bbc.com/future'],
#  'affective': ['https://www.bbc.com/future'],
#  'disorder': ['https://www.bbc.com/future'],
#  'dark': ['https://www.bbc.com/future'],
#  'shape': ['https://www.bbc.com/future'],
#  'mood': ['https://www.bbc.com/future'],
#  'intelligence': ['https://www.bbc.com/future'],
#  'sex': ['https://www.bbc.com/future'],
#  'drive': ['https://www.bbc.com/future'],
#  'best': ['https://www.bbc.com/future',
#   'https://www.bbc.com/culture',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/future/earth'],
#  'exercise': ['https://www.bbc.com/future'],
#  'tetri': ['https://www.bbc.com/future'],
#  'teenager': ['https://www.bbc.com/future'],
#  'achieved': ['https://www.bbc.com/future'],
#  'feat': ['https://www.bbc.com/future'],
#  'human': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'capability': ['https://www.bbc.com/future'],
#  'seaweed': ['https://www.bbc.com/future'],
#  'eating': ['https://www.bbc.com/future'],
#  'attractive': ['https://www.bbc.com/future'],
#  'improve': ['https://www.bbc.com/future'],
#  'according': ['https://www.bbc.com/future'],
#  'science': ['https://www.bbc.com/future'],
#  'future': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'earth': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'planet': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'health': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'gap': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'sustainability': ['https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'shoestring': ['https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'ultimate': ['https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'guide': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'giant': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'leap': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'green': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'tech': ['https://www.bbc.com/future', 'https://www.bbc.com/future/earth'],
#  'editor': ['https://www.bbc.com/future',
#   'https://www.bbc.com/culture',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife'],
#  'pick': ['https://www.bbc.com/future',
#   'https://www.bbc.com/culture',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife'],
#  'david': ['https://www.bbc.com/future'],
#  'cox': ['https://www.bbc.com/future'],
#  'jasmin': ['https://www.bbc.com/future'],
#  'carl': ['https://www.bbc.com/future'],
#  'nasman': ['https://www.bbc.com/future'],
#  'psychology': ['https://www.bbc.com/future'],
#  'fitness': ['https://www.bbc.com/future'],
#  'technology': ['https://www.bbc.com/future'],
#  'quick': ['https://www.bbc.com/future'],
#  'question': ['https://www.bbc.com/future',
#   'https://www.bbc.com/future/earth'],
#  'drama': ['https://www.bbc.com/culture'],
#  'shook': ['https://www.bbc.com/culture'],
#  'britain': ['https://www.bbc.com/culture'],
#  'rock': ['https://www.bbc.com/culture'],
#  'band': ['https://www.bbc.com/culture'],
#  'germany': ['https://www.bbc.com/culture'],
#  'image': ['https://www.bbc.com/culture'],
#  'shoe': ['https://www.bbc.com/culture'],
#  'make': ['https://www.bbc.com/culture'],
#  'star': ['https://www.bbc.com/culture'],
#  'trek': ['https://www.bbc.com/culture'],
#  'episode': ['https://www.bbc.com/culture'],
#  'predicted': ['https://www.bbc.com/culture'],
#  'crisis': ['https://www.bbc.com/culture',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife'],
#  'nordic': ['https://www.bbc.com/culture'],
#  'love': ['https://www.bbc.com/culture', 'https://www.bbc.com/travel'],
#  'sauna': ['https://www.bbc.com/culture'],
#  'controversial': ['https://www.bbc.com/culture'],
#  'culture': ['https://www.bbc.com/culture',
#   'https://www.bbc.com/travel',
#   'https://www.bbc.com/worklife'],
#  'moment': ['https://www.bbc.com/culture', 'https://www.bbc.com/future/earth'],
#  'iconic': ['https://www.bbc.com/culture'],
#  'portrait': ['https://www.bbc.com/culture'],
#  'art': ['https://www.bbc.com/culture'],
#  'book': ['https://www.bbc.com/culture'],
#  'style': ['https://www.bbc.com/culture'],
#  'identity': ['https://www.bbc.com/culture'],
#  'designed': ['https://www.bbc.com/culture'],
#  'collection': ['https://www.bbc.com/culture', 'https://www.bbc.com/travel'],
#  'laura': ['https://www.bbc.com/culture'],
#  'martin': ['https://www.bbc.com/culture'],
#  'clare': ['https://www.bbc.com/culture'],
#  'dowdy': ['https://www.bbc.com/culture'],
#  'hot': ['https://www.bbc.com/culture', 'https://www.bbc.com/travel'],
#  'topic': ['https://www.bbc.com/culture', 'https://www.bbc.com/travel'],
#  'central': ['https://www.bbc.com/travel'],
#  'asia': ['https://www.bbc.com/travel'],
#  'glittering': ['https://www.bbc.com/travel'],
#  'silk': ['https://www.bbc.com/travel'],
#  'road': ['https://www.bbc.com/travel'],
#  'jewel': ['https://www.bbc.com/travel'],
#  'island': ['https://www.bbc.com/travel'],
#  'thermal': ['https://www.bbc.com/travel'],
#  'spa': ['https://www.bbc.com/travel'],
#  'experience': ['https://www.bbc.com/travel'],
#  'travel': ['https://www.bbc.com/travel'],
#  'sustainably': ['https://www.bbc.com/travel'],
#  'table': ['https://www.bbc.com/travel'],
#  'doorway': ['https://www.bbc.com/travel'],
#  'another': ['https://www.bbc.com/travel'],
#  'cope': ['https://www.bbc.com/travel'],
#  'olive': ['https://www.bbc.com/travel'],
#  'never': ['https://www.bbc.com/travel'],
#  'heard': ['https://www.bbc.com/travel'],
#  'town': ['https://www.bbc.com/travel', 'https://www.bbc.com/future/earth'],
#  'drink': ['https://www.bbc.com/travel'],
#  'rome': ['https://www.bbc.com/travel'],
#  'greece': ['https://www.bbc.com/travel'],
#  'seeing': ['https://www.bbc.com/travel'],
#  'slow': ['https://www.bbc.com/travel'],
#  'decline': ['https://www.bbc.com/travel'],
#  'selfie': ['https://www.bbc.com/travel'],
#  'kibbeh': ['https://www.bbc.com/travel'],
#  'labaniyeh': ['https://www.bbc.com/travel'],
#  'lebanese': ['https://www.bbc.com/travel'],
#  'meatball': ['https://www.bbc.com/travel'],
#  'start': ['https://www.bbc.com/travel'],
#  'five': ['https://www.bbc.com/travel'],
#  'cash': ['https://www.bbc.com/travel'],
#  'belgian': ['https://www.bbc.com/travel'],
#  'waffle': ['https://www.bbc.com/travel'],
#  'brings': ['https://www.bbc.com/travel'],
#  'luck': ['https://www.bbc.com/travel'],
#  'soaring': ['https://www.bbc.com/travel'],
#  'ten': ['https://www.bbc.com/travel'],
#  'way': ['https://www.bbc.com/travel'],
#  'scam': ['https://www.bbc.com/travel'],
#  'booking': ['https://www.bbc.com/travel'],
#  'ca': ['https://www.bbc.com/travel', 'https://www.bbc.com/worklife'],
#  'perfected': ['https://www.bbc.com/travel'],
#  'sweden': ['https://www.bbc.com/travel'],
#  'enduring': ['https://www.bbc.com/travel'],
#  'cardamom': ['https://www.bbc.com/travel'],
#  'bun': ['https://www.bbc.com/travel'],
#  'food': ['https://www.bbc.com/travel', 'https://www.bbc.com/future/earth'],
#  'discovery': ['https://www.bbc.com/travel'],
#  'adventure': ['https://www.bbc.com/travel'],
#  'destination': ['https://www.bbc.com/travel'],
#  'untold': ['https://www.bbc.com/travel'],
#  'america': ['https://www.bbc.com/travel'],
#  'vivian': ['https://www.bbc.com/travel'],
#  'song': ['https://www.bbc.com/travel'],
#  'joan': ['https://www.bbc.com/travel'],
#  'mcfadden': ['https://www.bbc.com/travel'],
#  'living': ['https://www.bbc.com/travel'],
#  'dei': ['https://www.bbc.com/worklife'],
#  'backlash': ['https://www.bbc.com/worklife'],
#  'brewing': ['https://www.bbc.com/worklife'],
#  'reusable': ['https://www.bbc.com/worklife'],
#  'cup': ['https://www.bbc.com/worklife'],
#  'grocery': ['https://www.bbc.com/worklife'],
#  'tote': ['https://www.bbc.com/worklife'],
#  'become': ['https://www.bbc.com/worklife'],
#  'easier': ['https://www.bbc.com/worklife'],
#  'job': ['https://www.bbc.com/worklife'],
#  'canada': ['https://www.bbc.com/worklife'],
#  'burning': ['https://www.bbc.com/worklife'],
#  'man': ['https://www.bbc.com/worklife'],
#  'attend': ['https://www.bbc.com/worklife'],
#  'auto': ['https://www.bbc.com/worklife'],
#  'ceo': ['https://www.bbc.com/worklife'],
#  'retail': ['https://www.bbc.com/worklife'],
#  'makeover': ['https://www.bbc.com/worklife'],
#  'business': ['https://www.bbc.com/worklife'],
#  'staying': ['https://www.bbc.com/worklife'],
#  'russia': ['https://www.bbc.com/worklife'],
#  'costly': ['https://www.bbc.com/worklife'],
#  'economic': ['https://www.bbc.com/worklife'],
#  'trend': ['https://www.bbc.com/worklife'],
#  'stay': ['https://www.bbc.com/worklife'],
#  'yet': ['https://www.bbc.com/worklife'],
#  'worker': ['https://www.bbc.com/worklife'],
#  'quitting': ['https://www.bbc.com/worklife'],
#  'digital': ['https://www.bbc.com/worklife'],
#  'nomadism': ['https://www.bbc.com/worklife'],
#  'favourite': ['https://www.bbc.com/worklife'],
#  'brand': ['https://www.bbc.com/worklife'],
#  'taking': ['https://www.bbc.com/worklife'],
#  'social': ['https://www.bbc.com/worklife'],
#  'medium': ['https://www.bbc.com/worklife'],
#  'break': ['https://www.bbc.com/worklife'],
#  'much': ['https://www.bbc.com/worklife'],
#  'work': ['https://www.bbc.com/worklife'],
#  'shake': ['https://www.bbc.com/worklife'],
#  'presenteeism': ['https://www.bbc.com/worklife'],
#  'fuelling': ['https://www.bbc.com/worklife'],
#  'quits': ['https://www.bbc.com/worklife'],
#  'happens': ['https://www.bbc.com/worklife'],
#  'corporate': ['https://www.bbc.com/worklife'],
#  'retreat': ['https://www.bbc.com/worklife'],
#  'cross': ['https://www.bbc.com/worklife'],
#  'pivoting': ['https://www.bbc.com/worklife'],
#  'dream': ['https://www.bbc.com/worklife'],
#  'bridge': ['https://www.bbc.com/worklife'],
#  'career': ['https://www.bbc.com/worklife'],
#  'killer': ['https://www.bbc.com/worklife'],
#  'hustle': ['https://www.bbc.com/worklife'],
#  'worklife': ['https://www.bbc.com/worklife'],
#  'live': ['https://www.bbc.com/worklife'],
#  'elizabeth': ['https://www.bbc.com/worklife'],
#  'bennett': ['https://www.bbc.com/worklife'],
#  'jacqueline': ['https://www.bbc.com/worklife'],
#  'schneider': ['https://www.bbc.com/worklife'],
#  'finance': ['https://www.bbc.com/worklife'],
#  'economy': ['https://www.bbc.com/worklife'],
#  'emily': ['https://www.bbc.com/worklife'],
#  'earliest': ['https://www.bbc.com/reel'],
#  'riser': ['https://www.bbc.com/reel'],
#  'hiking': ['https://www.bbc.com/future/earth'],
#  'reclaim': ['https://www.bbc.com/future/earth'],
#  'space': ['https://www.bbc.com/future/earth'],
#  'article': ['https://www.bbc.com/future/earth'],
#  'banned': ['https://www.bbc.com/future/earth'],
#  'pollution': ['https://www.bbc.com/future/earth'],
#  'photo': ['https://www.bbc.com/future/earth'],
#  'shot': ['https://www.bbc.com/future/earth'],
#  'lithium': ['https://www.bbc.com/future/earth'],
#  'battery': ['https://www.bbc.com/future/earth'],
#  'energy': ['https://www.bbc.com/future/earth'],
#  'orca': ['https://www.bbc.com/future/earth'],
#  'hobby': ['https://www.bbc.com/future/earth'],
#  'ocean': ['https://www.bbc.com/future/earth'],
#  'powered': ['https://www.bbc.com/future/earth'],
#  'gravity': ['https://www.bbc.com/future/earth'],
#  'abandoned': ['https://www.bbc.com/future/earth'],
#  'coal': ['https://www.bbc.com/future/earth'],
#  'mine': ['https://www.bbc.com/future/earth'],
#  'hope': ['https://www.bbc.com/future/earth'],
#  'resilience': ['https://www.bbc.com/future/earth'],
#  'surface': ['https://www.bbc.com/future/earth'],
#  'cycling': ['https://www.bbc.com/future/earth'],
#  'capital': ['https://www.bbc.com/future/earth'],
#  'reindeer': ['https://www.bbc.com/future/earth'],
#  'keep': ['https://www.bbc.com/future/earth'],
#  'lapland': ['https://www.bbc.com/future/earth'],
#  'snowy': ['https://www.bbc.com/future/earth'],
#  'daredevil': ['https://www.bbc.com/future/earth'],
#  'flight': ['https://www.bbc.com/future/earth'],
#  'save': ['https://www.bbc.com/future/earth'],
#  'rare': ['https://www.bbc.com/future/earth'],
#  'bird': ['https://www.bbc.com/future/earth'],
#  'race': ['https://www.bbc.com/future/earth'],
#  'cow': ['https://www.bbc.com/future/earth'],
#  'burp': ['https://www.bbc.com/future/earth'],
#  'missed': ['https://www.bbc.com/future/earth'],
#  'cancelled': ['https://www.bbc.com/future/earth'],
#  'debt': ['https://www.bbc.com/future/earth'],
#  'cut': ['https://www.bbc.com/future/earth'],
#  'mile': ['https://www.bbc.com/future/earth'],
#  'colour': ['https://www.bbc.com/future/earth'],
#  'ever': ['https://www.bbc.com/future/earth'],
#  'bangladesh': ['https://www.bbc.com/future/earth'],
#  'support': ['https://www.bbc.com/future/earth'],
#  'refugee': ['https://www.bbc.com/future/earth'],
#  'matilda': ['https://www.bbc.com/future/earth'],
#  'welin': ['https://www.bbc.com/future/earth']}

# %%
res=search(["bbc", "accessibility"],crawler.inv_index)
res
# Out:
# ['https://www.bbc.com/culture',
#  'https://www.bbc.com/future',
#  'https://www.bbc.com/future/earth',
#  'https://www.bbc.com/news',
#  'https://www.bbc.com/reel',
#  'https://www.bbc.com/travel',
#  'https://www.bbc.com/usingthebbc/cookies/',
#  'https://www.bbc.com/usingthebbc/privacy/',
#  'https://www.bbc.com/weather',
#  'https://www.bbc.com/worklife']

# %%
res2 = sort_tf_idf(["bbc", "accessibility"], res, crawler)
res2
# Out:
# ['https://www.bbc.com/news',
#  'https://www.bbc.com/travel',
#  'https://www.bbc.com/worklife',
#  'https://www.bbc.com/future',
#  'https://www.bbc.com/culture',
#  'https://www.bbc.com/usingthebbc/privacy/',
#  'https://www.bbc.com/future/earth',
#  'https://www.bbc.com/usingthebbc/cookies/',
#  'https://www.bbc.com/weather',
#  'https://www.bbc.com/reel']

# %%
res3 = search_okapi_bm25f(["bbc", "accessibility"], crawler, res)
res3
# Out:
# ['https://www.bbc.com/reel',
#  'https://www.bbc.com/usingthebbc/cookies/',
#  'https://www.bbc.com/usingthebbc/privacy/',
#  'https://www.bbc.com/culture',
#  'https://www.bbc.com/weather',
#  'https://www.bbc.com/future/earth',
#  'https://www.bbc.com/future',
#  'https://www.bbc.com/worklife',
#  'https://www.bbc.com/travel',
#  'https://www.bbc.com/news']

# %% [markdown]
# # UI:

# %%
pip install PySimpleGUI
# Out:
# Collecting PySimpleGUI
#   Downloading PySimpleGUI-4.60.5-py3-none-any.whl (512 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.7/512.7 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: PySimpleGUI
# Successfully installed PySimpleGUI-4.60.5

# %%
import PySimpleGUI as sg
import webbrowser

sg.theme('LightGrey1')

crawler = Crawler()

layout = [
    [sg.Text('Enter URL:'), sg.InputText(key='url'), sg.Button('Crawl')],
    [sg.Text(f"Visited Links:")],
    [sg.Multiline(size=(65, 10), key='output', background_color='white', autoscroll=True)],
    [sg.Text('Search Word:'), sg.InputText(key='search_word'), sg.Button('Search')],
    [sg.Radio('None', "RADIO1", key='radio1', default=True),
     sg.Radio('tf_idf', "RADIO1", key='radio2'),
     sg.Radio('okapi_bm25f', "RADIO1", key='radio3')],
    [sg.Text('Search Result:')],
    [sg.Listbox(values=[], size=(60, 10), key='search_result', select_mode=sg.LISTBOX_SELECT_MODE_SINGLE)],
    [sg.Button('Visit Link'), sg.Button('Exit')]
]

window = sg.Window('Web Crawler', layout)

while True:
    event, values = window.read()
    if event in (sg.WIN_CLOSED, 'Exit'):
        break

    elif event == 'Crawl':
        url = values['url']
        if url.strip():
            try:
                crawler.crawl(url, 40)
                window['output'].update('\n'.join(crawler.visited_links))
            except Exception as e:
                sg.popup_error(f"Error while crawling: {e}")
        else:
            sg.popup_error("Please enter a valid URL.")

    elif event == 'Search':
        search_word = values['search_word']
        words = search_word.split()
        if search_word.strip():
            try:
                result = search(words, crawler.inv_index)

                if values['radio1']:
                    window['search_result'].update(result)
                elif values['radio2']:
                    res2 = sort_tf_idf(words, result, crawler)
                    window['search_result'].update(res2)
                elif values['radio3']:
                    res3 = search_okapi_bm25f(words, crawler, result)
                    window['search_result'].update(res3)
            except Exception as e:
                sg.popup_error(f"Error while searching: {e}")
        else:
            sg.popup_error("Please enter a search word.")

    elif event == 'Visit Link':
        selected_index = window['search_result'].get_indexes()[0]
        if 0 <= selected_index < len(result):
            link_to_visit = result[selected_index]
            webbrowser.open(link_to_visit)

window.close()
